# %% [markdown]
# # Laboratorio de regresión - 2

# %% [markdown]
# |                |   |
# :----------------|---|
# | **Nombre**     |  Adrian Marcelo Ballesteros Herrera |
# | **Fecha**      |  01-09-2025 |
# | **Expediente** | 750743  |

# %% [markdown]
# ## Regresión polinomial

# %% [markdown]
# Observa la siguiente gráfica.

# %%
import matplotlib.pyplot as plt; import numpy as np
# %matplotlib inline
np.random.seed(0)
x = np.linspace(-3, 3, 100); y = 1 + 4*x**2 + np.random.normal(0, 1, 100)
plt.figure(); plt.xlabel("x"); plt.ylabel("y")
plt.scatter(x, y); plt.grid()

# %% [markdown]
# Utiliza `sklearn` para realizar una regresión lineal simple ($\hat{y} = \hat{\beta_0} + \hat{\beta_1}x $)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
x=x.reshape(-1,1)
lr.fit(x,y)
print(f'Nuestra regresion nos da un resultado de y={lr.intercept_}+{lr.coef_}X')
# Out:
# Nuestra regresion nos da un resultado de y=13.30223225795873+[-0.04955448]X

# %% [markdown]
# Crea una gráfica donde se muestren las observaciones como una nube de puntos y la línea que ajustaste con regresión. Calcula el métrico $R^2$.

# %%
y_pred = lr.predict(x)

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', alpha=0.7, label='Datos reales')
plt.plot(x, y_pred, color='red', linewidth=2, 
         label=f'Regresión: y = {lr.coef_[0]:.2f}x + {lr.intercept_:.2f}')

plt.title('Gráfica de Dispersión con Regresión Lineal')
plt.xlabel('Variable X')
plt.ylabel('Variable Y')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
print(lr.score(x,y))
# Out:
# 5.80345273922811e-05

# %% [markdown]
# Podemos ver que el ajuste no es correcto, pues parece que tiene un comportamiento cuadrático y estamos intentando ajustar una línea recta.
#
# En lugar de hacer una regresión lineal simple, quizás podamos extender el modelo para que tenga varios factores dentro:
#
# $$ Y = \beta_0 + \beta_1 X + \beta_2 X^2 + ... + \beta_p X^p + \epsilon$$

# %% [markdown]
# Ajusta un modelo cuadrático con `sklearn` ($\hat{y} = \hat{\beta_0} + \hat{\beta_1}x + \hat{\beta_1}x^2 $) y calcula su $R^2$.

# %%
x2=x**2
xnew=np.hstack([x,x2])
lr.fit(xnew,y)
print(f'nuestra R^2 en este modelo cuadratico es de {lr.score(xnew,y)}')
# Out:
# nuestra R^2 en este modelo cuadratico es de 0.9934118040713642

# %% [markdown]
# Crea una gráfica con las observaciones y la nueva curva que ajustaste.

# %%
y_pred = lr.predict(xnew)

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', alpha=0.7, label='Datos reales')
plt.plot(x, y_pred, color='red', linewidth=2, 
         label=f'Regresión: y = {lr.coef_[1]:.2f}x^2{lr.coef_[0]:.2f}x + {lr.intercept_:.2f}')

plt.title('Gráfica de Dispersión con Regresión Lineal')
plt.xlabel('Variable X')
plt.ylabel('Variable Y')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# Ajusta modelos de grados 3, 5, 7, 9, y 11. Calcula su $R^2$.

# %%
x3=x**3
x4=x**4
x5=x**5
x6=x**6
x7=x**7
x8=x**8
x9=x**9
x10=x**10
x11=x**11

# %%
xnew2=np.hstack([xnew,x3])
lr.fit(xnew2,y)
print(f'nuestra R^2 en este modelo cuadratico es de {lr.score(xnew2,y)}')
lr.intercept_
lr.coef_
# Out:
# nuestra R^2 en este modelo cuadratico es de 0.9934129585186598
# array([-6.55753967e-02,  4.14388884e+00,  2.90847549e-03])

# %%
xnew3=np.hstack([xnew2,x4,x5])
lr.fit(xnew3,y)
print(f'nuestra R^2 en este modelo cuadratico es de {lr.score(xnew3,y)}')
# Out:
# nuestra R^2 en este modelo cuadratico es de 0.9934954953676421

# %%
xnew4=np.hstack([xnew3,x6,x7])
lr.fit(xnew4,y)
print(f'nuestra R^2 en este modelo cuadratico es de {lr.score(xnew4,y)}')
# Out:
# nuestra R^2 en este modelo cuadratico es de 0.9935089341876935

# %%
xnew5=np.hstack([xnew4,x8,x9])
lr.fit(xnew5,y)
print(f'nuestra R^2 en este modelo cuadratico es de {lr.score(xnew5,y)}')
# Out:
# nuestra R^2 en este modelo cuadratico es de 0.9935141799662259

# %%
xnew6=np.hstack([xnew5,x10,x11])
lr.fit(xnew6,y)
print(f'nuestra R^2 en este modelo cuadratico es de {lr.score(xnew6,y)}')
# Out:
# nuestra R^2 en este modelo cuadratico es de 0.9935338704150221

# %% [markdown]
# Crea una gráfica por cada modelo con las observaciones y su curva.

# %%
y_pred = lr.predict(xnew2)

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', alpha=0.7, label='Datos reales')
plt.plot(x, y_pred, color='red', linewidth=2, 
         )

plt.title('Gráfica de Dispersión con Regresión Lineal')
plt.xlabel('Variable X')
plt.ylabel('Variable Y')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
y_pred = lr.predict(xnew3)

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', alpha=0.7, label='Datos reales')
plt.plot(x, y_pred, color='red', linewidth=2, 
         )

plt.title('Gráfica de Dispersión con Regresión Lineal')
plt.xlabel('Variable X')
plt.ylabel('Variable Y')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
y_pred = lr.predict(xnew4)

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', alpha=0.7, label='Datos reales')
plt.plot(x, y_pred, color='red', linewidth=2, 
         )

plt.title('Gráfica de Dispersión con Regresión Lineal')
plt.xlabel('Variable X')
plt.ylabel('Variable Y')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
y_pred = lr.predict(xnew5)

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', alpha=0.7, label='Datos reales')
plt.plot(x, y_pred, color='red', linewidth=2, 
         )

plt.title('Gráfica de Dispersión con Regresión Lineal')
plt.xlabel('Variable X')
plt.ylabel('Variable Y')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
y_pred = lr.predict(xnew6)

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', alpha=0.7, label='Datos reales')
plt.plot(x, y_pred, color='red', linewidth=2, 
         )

plt.title('Gráfica de Dispersión con Regresión Lineal')
plt.xlabel('Variable X')
plt.ylabel('Variable Y')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# **¿Cuál modelo consideras que es mejor? ¿Por qué?**

# %% [markdown]
#  A simple vista diria que el de grado 11 por que su $R^2$ es el mas alto pero no cambia casi nada del de grado dos por lo que se vuelve demasiado complejo, tiene muchos coeficientes para un cambio muy pequeño, se deberia de hacer una prueba de hipotesis para ver que coeficientes realmente valen la pena o no pero me quedaria con el de grado 2

# %% [markdown]
# Recuerda que una de las metas de ajustar modelos es para poder interpolar y extrapolar. Los datos que tenemos mantienen $x \in [-3, 3]$. ¿Qué pasaría si quisiéramos saber el valor de $y$ cuando $x=5$?
#
# Calcula la predicción $\hat{y}$ para todos los modelos creados (grados 2, 3, 5, 7, 9, y 11).

# %%
xnueva=np.array([5])
xn=xnueva.reshape(-1,1)
x2_n=xn**2
X2_n=np.hstack([xn,x2_n])
y2_pred=lr.predict(X2_n)
print(f'el valor de x=5 cuando tenemos una grafica de grado 2 es:{y2_pred}')
# Out:
# el valor de x=5 cuando tenemos una grafica de grado 2 es:[103.96886955]

# %%
x3_n=xn**3
X3_n=np.hstack([xn,x2_n,x3_n])
y3_pred=lr.predict(X3_n)
print(f'el valor de x=5 cuando tenemos una grafica de grado 3 es:{y3_pred}')
# Out:
# el valor de x=5 cuando tenemos una grafica de grado 2 es:[104.25232439]

# %%
x4_n=xn**4
x5_n=xn**5
X5_n=np.hstack([xn,x2_n,x3_n,x4_n,x5_n])
y5_pred=lr.predict(X5_n)
print(f'el valor de x=5 cuando tenemos una grafica de grado 5 es:{y5_pred}')
# Out:
# el valor de x=5 cuando tenemos una grafica de grado 5 es:[84.59895013]

# %%
x6_n=xn**6
x7_n=xn**7
X7_n=np.hstack([xn,x2_n,x3_n,x4_n,x5_n,x6_n,x7_n])
y7_pred=lr.predict(X7_n)
print(f'el valor de x=5 cuando tenemos una grafica de grado 7 es:{y7_pred}')
# Out:
# el valor de x=5 cuando tenemos una grafica de grado 7 es:[33.74321848]

# %% [markdown]
# ¿Cuál modelo crees que sea mejor?

# %%
x8_n=xn**8
x9_n=xn**9
X9_n=np.hstack([xn,x2_n,x3_n,x4_n,x5_n,x6_n,x7_n,x8_n,x9_n])
y9_pred=lr.predict(X9_n)
print(f'el valor de x=5 cuando tenemos una grafica de grado 9 es:{y9_pred}')
# Out:
# el valor de x=5 cuando tenemos una grafica de grado 9 es:[215.73637926]

# %%
x10_n=xn**10
x11_n=xn**11
X11_n=np.hstack([xn,x2_n,x3_n,x4_n,x5_n,x6_n,x7_n,x8_n,x9_n,x10_n,x11_n])
y11_pred=lr.predict(X11_n)
print(f'el valor de x=5 cuando tenemos una grafica de grado 9 es:{y11_pred}')
# Out:
# el valor de x=5 cuando tenemos una grafica de grado 9 es:[-5265.34425348]

# %% [markdown]
# ## Referencia
#
# James, G., Witten, D., Hastie, T., Tibshirani, R.,, Taylor, J. (2023). An Introduction to Statistical Learning with Applications in Python. Cham: Springer. ISBN: 978-3-031-38746-3
